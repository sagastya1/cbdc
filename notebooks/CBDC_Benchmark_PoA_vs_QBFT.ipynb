# %% [markdown]
# # 🏦 CBDC Transaction Benchmark: PoA vs QBFT
# > **Automated framework to evaluate CBDC performance on Hyperledger Besu**
# >
# > Measures: TPS · Latency · Block Time · Finality
# >
# > Run each cell top-to-bottom. Full run takes ~15-20 mins.

# %% [markdown]
# ## ⚙️ Cell 1 — System Setup (Java, Git, Deps)

# %%
# ══════════════════════════════════════════════════════
# CELL 1: System Setup
# ══════════════════════════════════════════════════════

import subprocess, sys, os

def run(cmd, **kw):
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True, **kw)
    if result.returncode != 0:
        print(result.stderr[-2000:])
    return result

print('Installing Java 21...')
run('apt-get update -qq && apt-get install -y openjdk-21-jre-headless -qq')
print('Java:', run('java -version').stderr.strip()[:60])

print('Installing Python packages...')
run('pip install -q web3 py-solc-x pandas openpyxl matplotlib numpy')

print('Downloading Besu 24.1.2...')
run('mkdir -p /opt/besu')
r = run('wget -q https://hyperledger.jfrog.io/artifactory/besu-binaries/besu/24.1.2/besu-24.1.2.tar.gz -O /tmp/besu.tar.gz')
run('tar -xzf /tmp/besu.tar.gz -C /opt/besu --strip-components=1')
print('Besu:', run('/opt/besu/bin/besu --version').stdout.strip()[:80])

print('\n✅ Setup complete!')
# Out:
# Installing Java 21...
# Java: openjdk version "21.0.10" 2026-01-20
# OpenJDK Runtime Environ
# Installing Python packages...
# Downloading Besu 24.1.2...
# Besu: [0.001s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup
#
# ✅ Setup complete!

# %% [markdown]
# ## 📦 Cell 2 — Clone Repository & Upload Dataset

# %%
# ══════════════════════════════════════════════════════
# CELL 2: Git Clone + Dataset Upload
# ══════════════════════════════════════════════════════

import os
from google.colab import files

# ── Option A: Clone from GitHub ───────────────────────
GITHUB_REPO = 'sagastya1/cbdc-besu-benchmark'  # ← CHANGE THIS
GITHUB_TOKEN = ''  # ← Set for private repos (or use Colab secrets)

# Try to read token from Colab secrets
try:
    from google.colab import userdata
    GITHUB_TOKEN = userdata.get('GITHUB_TOKEN') or GITHUB_TOKEN
except Exception:
    pass

if GITHUB_TOKEN:
    clone_url = f'https://{GITHUB_TOKEN}@github.com/{GITHUB_REPO}.git'
else:
    clone_url = f'https://github.com/{GITHUB_REPO}.git'

os.chdir('/content')

if os.path.exists('/content/cbdc-besu-benchmark'):
    print('Repo already cloned, pulling latest...')
    os.chdir('/content/cbdc-besu-benchmark')
    run('git pull')
else:
    print(f'Cloning {GITHUB_REPO}...')
    r = run(f'git clone {clone_url} /content/cbdc-besu-benchmark')
    os.chdir('/content/cbdc-besu-benchmark')

print('Working dir:', os.getcwd())

# ── Upload dataset ─────────────────────────────────────
DATASET_PATH = '/content/cbdc-besu-benchmark/FinalDataset.xlsx'

if not os.path.exists(DATASET_PATH):
    print('\n📂 Upload FinalDataset.xlsx:')
    uploaded = files.upload()
    for fname in uploaded:
        os.rename(f'/content/{fname}', DATASET_PATH)
        print(f'✅ Dataset saved: {DATASET_PATH}')
else:
    print(f'✅ Dataset found: {DATASET_PATH}')

# Set env for push script
os.environ['GITHUB_TOKEN'] = GITHUB_TOKEN
os.environ['GITHUB_REPO']  = GITHUB_REPO
# Out:
# Repo already cloned, pulling latest...
# Working dir: /content/cbdc-besu-benchmark
# ✅ Dataset found: /content/cbdc-besu-benchmark/FinalDataset.xlsx

# %% [markdown]
# ## 🚀 Cell 3 — One-Command Benchmark Run

# %%
# ══════════════════════════════════════════════════════
# CELL 3: Run Full Benchmark (One Command)
# ══════════════════════════════════════════════════════

import subprocess, os

os.chdir('/content/cbdc-besu-benchmark')
os.environ['PATH'] = '/opt/besu/bin:' + os.environ['PATH']

# ── CONFIG ─────────────────────────────────────────────
TXNS = 100    # Number of transactions per consensus
TPS  = 50     # Max TPS controller cap
PUSH = False  # Set True to push results to GitHub
# ───────────────────────────────────────────────────────

push_flag = '--push' if PUSH else ''
cmd = f'bash run_benchmark.sh --txns {TXNS} --tps {TPS} --dataset FinalDataset.xlsx {push_flag}'
print(f'Running: {cmd}\n')

process = subprocess.Popen(
    cmd, shell=True, stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT, text=True, bufsize=1
)
for line in process.stdout:
    print(line, end='')
process.wait()

if process.returncode == 0:
    print('\n✅ Benchmark finished successfully!')
else:
    print(f'\n❌ Benchmark failed (exit code {process.returncode})')
# Out:
# Running: bash run_benchmark.sh --txns 100 --tps 50 --dataset FinalDataset.xlsx
#
#
# ╔══════════════════════════════════════════════════╗
# ║   CBDC Blockchain Benchmark: PoA vs QBFT        ║
# ║   Txns: 100  |  TPS Cap: 50            ║
# ╚══════════════════════════════════════════════════╝
#
# ==> [1/7] Installing Python dependencies...
# ==> [2/7] Setting up Java & Besu...
#  19175==> Starting Besu poa on port 8545...
# PID: 23568
# Waiting for node....
# Node READY on port 8545 (block #1)
#
# ==> [3/7] Starting QBFT network...
#  19458Generating QBFT genesis via Besu operator...
# [0.001s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.001s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# 2026-03-01 23:35:15.956+00:00 | main | INFO  | GenerateBlockchainConfig | Generating 1 nodes keys.
# 2026-03-01 23:35:15.966+00:00 | main | INFO  | GenerateBlockchainConfig | Generating keypair for node 0.
# 2026-03-01 23:35:16.083+00:00 | main | INFO  | GenerateBlockchainConfig | Generating QBFT extra data.
# 2026-03-01 23:35:16.092+00:00 | main | INFO  | GenerateBlockchainConfig | Writing genesis file.
# Validator key installed.
# ==> Starting Besu qbft on port 8546...
# PID: 23849
# Waiting for node....
# Node READY on port 8546 (block #3)
#
# ==> [4/7] Running PoA (Clique) benchmark...
# /content/cbdc-besu-benchmark/benchmark/benchmark_client.py:332: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp":       datetime.utcnow().isoformat(),
# [+] Connected to poa node. Chain ID: 1337
# [+] Waiting for 2 blocks to confirm sealer is active...
# [+] Block #2 confirmed — sealer active.
# [+] CBDC contract deployed at: 0x42699A7612A82f1d9C36148af9C77354759b210b
# [+] Loading dataset: FinalDataset.xlsx
# [+] Loaded 100 transactions from dataset
# [+] Seeded 20 accounts
#
# [+] Starting benchmark: 100 txns @ 50.0 TPS cap
#     Sent 1/100 | TPS: 22.3 | Errors: 0
#     Sent 51/100 | TPS: 43.5 | Errors: 0
#
# [+] All transactions sent in 2.44s
# [+] Waiting for finality...
#
# =======================================================
#   BENCHMARK RESULTS — POA
# =======================================================
#   Transactions:   100/100 confirmed
#   Actual TPS:     6.17
#   Avg Latency:    14513.3 ms
#   P95 Latency:    14991.9 ms
#   Avg Block Time: 15.00s
#   Finality Time:  16.20s
#   Blocks Used:    1
# =======================================================
#   Results saved to: results/
#
# ==> [5/7] Running QBFT benchmark...
# /content/cbdc-besu-benchmark/benchmark/benchmark_client.py:332: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp":       datetime.utcnow().isoformat(),
# [+] Connected to qbft node. Chain ID: 1338
# [+] Waiting for 2 blocks to confirm sealer is active...
# [+] Block #23 confirmed — sealer active.
# [+] CBDC contract deployed at: 0x42699A7612A82f1d9C36148af9C77354759b210b
# [+] Loading dataset: FinalDataset.xlsx
# [+] Loaded 100 transactions from dataset
# [+] Seeded 20 accounts
#
# [+] Starting benchmark: 100 txns @ 50.0 TPS cap
#     Sent 1/100 | TPS: 20.7 | Errors: 0
#     Sent 51/100 | TPS: 34.7 | Errors: 0
#
# [+] All transactions sent in 2.69s
# [+] Waiting for finality...
#
# =======================================================
#   BENCHMARK RESULTS — QBFT
# =======================================================
#   Transactions:   100/100 confirmed
#   Actual TPS:     23.24
#   Avg Latency:    2004.4 ms
#   P95 Latency:    2608.2 ms
#   Avg Block Time: 2.00s
#   Finality Time:  4.30s
#   Blocks Used:    2
# =======================================================
#   Results saved to: results/
#
# ==> [6/7] Generating comparison graphs...
# [+] Generating graphs and comparison report...
# [+] Saved tps_comparison.png
# [+] Saved latency_cdf.png
# [+] Saved block_times.png
# [+] Saved dashboard.png
# [+] Saved comparison_summary.csv
#
#      Network    TPS  Avg Latency (ms)  P95 Latency (ms)  Avg Block Time (s)  Finality Time (s)  Confirmed Txns  Errors  Blocks Used
# PoA (Clique)  6.172           14513.3           14991.9                  15             16.202             100       0            1
#         QBFT 23.236            2004.4            2608.2                   2              4.304             100       0            2
#
# [+] All outputs saved to results/graphs/
# ==> Stopping Besu nodes...
#     Stopped poa node
#     Stopped qbft node
# ==> [7/7] Skipping GitHub push (use --push to enable)
#
# ╔══════════════════════════════════════════════════╗
# ║   ✓ Benchmark COMPLETE                          ║
# ║   Results: ./results/                           ║
# ║   Graphs:  ./results/graphs/                    ║
# ╚══════════════════════════════════════════════════╝
#
# ✅ Benchmark finished successfully!

# %% [markdown]
# ## 📊 Cell 4 — Display Results & Graphs

# %%
# ══════════════════════════════════════════════════════
# CELL 4: Display Results
# ══════════════════════════════════════════════════════

import json, pandas as pd
from IPython.display import Image, display
from pathlib import Path

os.chdir('/content/cbdc-besu-benchmark')

# ── Summary table ──────────────────────────────────────
summary_path = Path('results/comparison_summary.csv')
if summary_path.exists():
    df = pd.read_csv(summary_path)
    print('\n=== BENCHMARK SUMMARY ===')
    display(df)

# ── Individual metrics ─────────────────────────────────
for net in ['poa', 'qbft']:
    p = Path(f'results/metrics_{net}.json')
    if p.exists():
        m = json.loads(p.read_text())
        print(f'\n--- {net.upper()} Metrics ---')
        for k, v in m.items():
            print(f'  {k:30s}: {v}')

# ── Graphs ─────────────────────────────────────────────
graphs_dir = Path('results/graphs')
for img in ['dashboard.png', 'tps_comparison.png', 'latency_cdf.png', 'block_times.png']:
    img_path = graphs_dir / img
    if img_path.exists():
        print(f'\n--- {img} ---')
        display(Image(str(img_path), width=850))
# Out:
# === BENCHMARK SUMMARY ===
#         Network     TPS  Avg Latency (ms)  P95 Latency (ms)  \
# 0  PoA (Clique)   6.172           14513.3           14991.9
# 1          QBFT  23.236            2004.4            2608.2
#
#    Avg Block Time (s)  Finality Time (s)  Confirmed Txns  Errors  Blocks Used
# 0                  15             16.202             100       0            1
# 1                   2              4.304             100       0            2
# --- POA Metrics ---
#   network                       : poa
#   timestamp                     : 2026-03-01T23:36:06.365766
#   transactions_sent             : 100
#   transactions_confirmed        : 100
#   errors                        : 0
#   tps_cap                       : 50.0
#   actual_tps                    : 6.172
#   avg_latency_s                 : 14.5133
#   p95_latency_s                 : 14.9919
#   min_latency_s                 : 13.7699
#   max_latency_s                 : 15.0916
#   avg_block_time_s              : 15
#   finality_time_s               : 16.202
#   blocks_used                   : 1
#   contract_address              : 0x42699A7612A82f1d9C36148af9C77354759b210b
#
# --- QBFT Metrics ---
#   network                       : qbft
#   timestamp                     : 2026-03-01T23:36:18.504498
#   transactions_sent             : 100
#   transactions_confirmed        : 100
#   errors                        : 0
#   tps_cap                       : 50.0
#   actual_tps                    : 23.236
#   avg_latency_s                 : 2.0044
#   p95_latency_s                 : 2.6082
#   min_latency_s                 : 1.6235
#   max_latency_s                 : 2.667
#   avg_block_time_s              : 2
#   finality_time_s               : 4.304
#   blocks_used                   : 2
#   contract_address              : 0x42699A7612A82f1d9C36148af9C77354759b210b
#
# --- dashboard.png ---
# --- tps_comparison.png ---
# --- latency_cdf.png ---
# --- block_times.png ---

# %% [markdown]
# ## 💾 Cell 5 — Download Results

# %%
# ══════════════════════════════════════════════════════
# CELL 5: Download All Results as ZIP
# ══════════════════════════════════════════════════════

import shutil, os
from google.colab import files

os.chdir('/content/cbdc-besu-benchmark')

# Package results
shutil.make_archive('/content/cbdc_benchmark_results', 'zip', 'results')
files.download('/content/cbdc_benchmark_results.zip')
print('✅ Results downloaded!')
# Out:
# ✅ Results downloaded!

# %% [markdown]
# ## 🔁 Cell 6 — Push Results to GitHub (Optional)

# %%
# ══════════════════════════════════════════════════════
# CELL 6: Push to GitHub
# ══════════════════════════════════════════════════════
# Set GITHUB_TOKEN in Colab Secrets (🔑 icon in sidebar)

import subprocess, os

try:
    from google.colab import userdata
    os.environ['GITHUB_TOKEN'] = userdata.get('GITHUB_TOKEN') or ''
    os.environ['GITHUB_REPO']  = userdata.get('GITHUB_REPO') or 'your-username/cbdc-besu-benchmark'
except Exception:
    pass

os.chdir('/content/cbdc-besu-benchmark')
result = subprocess.run('bash scripts/push_results.sh', shell=True,
                        capture_output=True, text=True)
print(result.stdout)
if result.stderr: print(result.stderr)
# Out:
# [!] GITHUB_TOKEN not set. Skipping push.
#     Set it with: export GITHUB_TOKEN=ghp_yourtoken
